# %% [markdown]
# # TESS TRAIN TEST RAVDEDD

# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
import random

# ── PARAMETERS ──────────────────────────────────────────────────────────────
tess_dir = r"C:\Users\okh96\OneDrive - Toronto Metropolitan University (TMU)\TMU_D2L\EE8104 - Adaptive Signal Processing\Assignment5B\TESSdataset"

sr = 16000        # Sampling rate
n_mfcc = 20       # Number of MFCCs
max_length = 85   # Number of frames in MFCC

# ── EMOTION LABEL MAPPING ───────────────────────────────────────────────────
emotion_map = {
    'angry': 0,
    'disgust': 1,
    'fear': 2,
    'happy': 3,
    'neutral': 4,
    'pleasant_surprised': 5,  # handle alternate spelling
    'sad': 6
}

# ── MFCC EXTRACTION FUNCTION ────────────────────────────────────────────────
def extract_mfcc(file_path, max_length=85):
    y, _ = librosa.load(file_path, sr=sr)
    hop_length = int(len(y) / (max_length - 1))
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
    if mfcc.shape[1] < max_length:
        pad_width = max_length - mfcc.shape[1]
        mfcc = np.pad(mfcc, ((0, 0), (0, pad_width)), mode='constant')
    elif mfcc.shape[1] > max_length:
        mfcc = mfcc[:, :max_length]
    return mfcc

# ── GENERAL DATA LOADER FUNCTION FOR RAVDESS ────────────────────────────────
def load_all_data(base_dir):
    data = []
    labels = []
    for emotion in os.listdir(base_dir):
        emotion_path = os.path.join(base_dir, emotion)
        if not os.path.isdir(emotion_path):
            continue
        label = emotion_map.get(emotion.lower())
        if label is None:
            print(f"Skipping unknown emotion folder: {emotion}")
            continue
        for file in os.listdir(emotion_path):
            file_path = os.path.join(emotion_path, file)
            try:
                mfcc = extract_mfcc(file_path, max_length)
                mfcc = np.expand_dims(mfcc, axis=-1)
                data.append(mfcc)
                labels.append(label)
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
    return np.array(data), np.array(labels)

# ── LOAD AND SPLIT tess DATA ─────────────────────────────────────────────
X_all, y_all = load_all_data(tess_dir)

# Shuffle and split into train, val, test (70/15/15)
X_temp, X_test, y_temp, y_test = train_test_split(X_all, y_all, test_size=0.15, random_state=42, stratify=y_all)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.1765, random_state=42, stratify=y_temp)  # 0.1765 * 0.85 ≈ 0.15

print("Train data shape:", X_train.shape)
print("Validation data shape:", X_val.shape)
print("Test data shape:", X_test.shape)

# ── DEFINE CNN MODEL ────────────────────────────────────────────────────────
class EmotionClassifier(tf.keras.Model):
    def __init__(self, num_classes):
        super(EmotionClassifier, self).__init__()
        self.weight_decay = 1e-4
        
        # First Conv Block
        self.conv1 = layers.Conv2D(32, 3, padding='same',
                                 kernel_regularizer=regularizers.l2(self.weight_decay))
        self.bn1 = layers.BatchNormalization()
        self.act1 = layers.Activation('relu')
        self.pool1 = layers.MaxPooling2D(2)
        self.drop1 = layers.Dropout(0.3)
        
        # Second Conv Block
        self.conv2 = layers.Conv2D(64, 3, padding='same',
                                 kernel_regularizer=regularizers.l2(self.weight_decay))
        self.bn2 = layers.BatchNormalization()
        self.act2 = layers.Activation('relu')
        self.pool2 = layers.MaxPooling2D(2)
        self.drop2 = layers.Dropout(0.3)
        
        # Third Conv Block
        self.conv3 = layers.Conv2D(128, 3, padding='same',
                                 kernel_regularizer=regularizers.l2(self.weight_decay))
        self.bn3 = layers.BatchNormalization()
        self.act3 = layers.Activation('relu')
        self.pool3 = layers.MaxPooling2D(2)
        self.drop3 = layers.Dropout(0.3)
        
        # Dense Layers
        self.flatten = layers.Flatten()
        self.dense1 = layers.Dense(128, activation='relu',
                                kernel_regularizer=regularizers.l2(self.weight_decay))
        self.drop4 = layers.Dropout(0.4)
        self.dense2 = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs, training=False):
        # First Conv Block
        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        x = self.act1(x)
        x = self.pool1(x)
        x = self.drop1(x, training=training)
        
        # Second Conv Block
        x = self.conv2(x)
        x = self.bn2(x, training=training)
        x = self.act2(x)
        x = self.pool2(x)
        x = self.drop2(x, training=training)
        
        # Third Conv Block
        x = self.conv3(x)
        x = self.bn3(x, training=training)
        x = self.act3(x)
        x = self.pool3(x)
        x = self.drop3(x, training=training)
        
        # Dense Layers
        x = self.flatten(x)
        x = self.dense1(x)
        x = self.drop4(x, training=training)
        return self.dense2(x)

# ── COMPILE AND TRAIN ───────────────────────────────────────────────────────
num_classes = len(emotion_map)

model = EmotionClassifier(num_classes)
model.build(input_shape=(None, n_mfcc, max_length, 1))  # define input shape
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Optional: TensorBoard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='logs/emotion_classifier', histogram_freq=1)

model.fit(X_train, y_train,
          epochs=50,
          validation_data=(X_val, y_val),
          callbacks=[tensorboard_callback])

# ── EVALUATE ────────────────────────────────────────────────────────────────
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_acc)
# Out:
# Train data shape: (1959, 20, 85, 1)
# Validation data shape: (421, 20, 85, 1)
# Test data shape: (420, 20, 85, 1)
# Epoch 1/50
# 62/62 [==============================] - 2s 17ms/step - loss: 2.2063 - accuracy: 0.2103 - val_loss: 1.8648 - val_accuracy: 0.2708
# Epoch 2/50
# 62/62 [==============================] - 1s 15ms/step - loss: 1.5352 - accuracy: 0.3645 - val_loss: 0.9127 - val_accuracy: 0.7767
# Epoch 3/50
# 62/62 [==============================] - 1s 15ms/step - loss: 0.9293 - accuracy: 0.6136 - val_loss: 0.5007 - val_accuracy: 0.8979
# Epoch 4/50
# 62/62 [==============================] - 1s 14ms/step - loss: 0.7142 - accuracy: 0.7121 - val_loss: 0.3464 - val_accuracy: 0.9240
# Epoch 5/50
# 62/62 [==============================] - 1s 14ms/step - loss: 0.5873 - accuracy: 0.7856 - val_loss: 0.2367 - val_accuracy: 0.9644
# Epoch 6/50
# 62/62 [==============================] - 1s 15ms/step - loss: 0.5056 - accuracy: 0.8035 - val_loss: 0.1727 - val_accuracy: 0.9857
# Epoch 7/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4106 - accuracy: 0.8525 - val_loss: 0.1615 - val_accuracy: 0.9786
# Epoch 8/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3934 - accuracy: 0.8622 - val_loss: 0.1521 - val_accuracy: 0.9786
# Epoch 9/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3497 - accuracy: 0.8775 - val_loss: 0.1376 - val_accuracy: 0.9857
# Epoch 10/50
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3293 - accuracy: 0.8887 - val_loss: 0.1393 - val_accuracy: 0.9810
# Epoch 11/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0
50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.1135 - accuracy: 0.9699 - val_loss: 0.0504 - val_accuracy: 0.9976
# Epoch 39/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1224 - accuracy: 0.9648 - val_loss: 0.0627 - val_accuracy: 0.9952
# Epoch 40/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1553 - accuracy: 0.9576 - val_loss: 0.0553 - val_accuracy: 0.9976
# Epoch 41/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1110 - accuracy: 0.9689 - val_loss: 0.0488 - val_accuracy: 0.9976
# Epoch 42/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1021 - accuracy: 0.9745 - val_loss: 0.0554 - val_accuracy: 0.9929
# Epoch 43/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.1191 - accuracy: 0.9658 - val_loss: 0.0536 - val_accuracy: 0.9952
# Epoch 44/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1079 - accuracy: 0.9673 - val_loss: 0.0545 - val_accuracy: 0.9952
# Epoch 45/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.1115 - accuracy: 0.9714 - val_loss: 0.0450 - val_accuracy: 0.9976
# Epoch 46/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0944 - accuracy: 0.9791 - val_loss: 0.0575 - val_accuracy: 0.9952
# Epoch 47/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.1143 - accuracy: 0.9689 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 48/50
# 62/62 [==============================] - 1s 12ms/step - loss: 0.1104 - accuracy: 0.9668 - val_loss: 0.0488 - val_accuracy: 0.9976
# Epoch 49/50
# 62/62 [==============================] - 1s 13ms/step - loss: 0.1062 - accuracy: 0.9689 - val_loss: 0.0549 - val_accuracy: 0.9976
# Epoch 50/50
# 62/62 [==============================] - 1s 14ms/step - loss: 0.1118 - accuracy: 0.9699 - val_loss: 0.0554 - val_accuracy: 0.9976
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 1.0000
# Test loss: 0.041841182857751846
# Test accuracy: 1.0

# %%
# ── TEST ON FULL RAVDESS-BY-EMOTION FOLDER ───────────────────────────────────
# Re-load full dataset (ensure same pre-processing as before)
ravdess_dir = r"C:\Users\okh96\OneDrive - Toronto Metropolitan University (TMU)\TMU_D2L\EE8104 - Adaptive Signal Processing\Assignment5B\ravdess_by_emotion"

X_full, y_full = load_all_data(ravdess_dir)

# Predict
y_pred_probs = model.predict(X_full)
y_pred = np.argmax(y_pred_probs, axis=1)

# Calculate accuracy
accuracy = np.mean(y_pred == y_full)
print("Full RAVDESS dataset accuracy:", accuracy)
# Out:
# 39/39 [==============================] - 0s 9ms/step
# Full RAVDESS dataset accuracy: 0.2219551282051282

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Classification report
print(classification_report(y_full, y_pred, target_names=emotion_map.keys()))

# Confusion matrix
cm = confusion_matrix(y_full, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=emotion_map.keys(), yticklabels=emotion_map.keys())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix on Full RAVDESS Dataset")
plt.show()
# Out:
#                     precision    recall  f1-score   support
#
#              angry       0.25      0.23      0.24       192
#            disgust       0.26      0.15      0.19       192
#               fear       0.19      0.48      0.28       192
#              happy       0.11      0.01      0.01       192
#            neutral       0.67      0.02      0.04        96
# pleasant_surprised       0.00      0.00      0.00       192
#                sad       0.23      0.57      0.33       192
#
#           accuracy                           0.22      1248
#          macro avg       0.24      0.21      0.16      1248
#       weighted avg       0.21      0.22      0.16      1248
